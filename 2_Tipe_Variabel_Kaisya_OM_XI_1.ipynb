# %% [markdown]
# <a href="https://colab.research.google.com/github/kaisyaoktina/KKASemester1/blob/main/2_Tipe_Variabel_Kaisya_OM_XI_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Kaisya Oktina Mawaddah
#
# Kelas : XI-1
#
# No.absen : 21

# %% [markdown]
# #Konsep Dasar

# %%
email_user_1 = "kaisyaoktina.2025@gmail.com"
print(email_user_1)
# Out:
# kaisyaoktina.2025@gmail.com

# %%
sabun_shinzui = 10000

print(sabun_shinzui)
# Out:
# 10000

# %%
print(sabun_shinzui*5)
# Out:
# 50000

# %% [markdown]
# #Peraturan Penulisan Variabel

# %%
# Penulisan variabel hanya boleh menggunakan huruf, angka, dan underscore
# Tidak boleh menggunakan spasi

nama siswa = "Kaisya"

print(nama siswa)
# Out:
#   File "/tmp/ipython-input-3625216406.py", line 3
#     nama siswa = "Kaisya"
#          ^
# SyntaxError: invalid syntax

# %%
# Tidak boleh diawali dengan angka

1_nama_siswa = "Kaisya"

print(1_nama_siswa)
# Out:
#   File "/tmp/ipython-input-1047313416.py", line 3
#     1_nama_siswa = "Kaisya"
#      ^
# SyntaxError: invalid decimal literal

# %%
# Penulisan variabel itu case sensitive/sensitif capslock

nama_siswa_1 = "Kaisya"

print(Nama_siswa_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3858867655.py in <cell line: 0>()
#       2 nama_siswa_1 = "Kaisya"
#       3
# ----> 4 print(Nama_siswa_1)
#
# NameError: name 'Nama_siswa_1' is not defined

# %%
# Dilarang menggunakan kata kunci di Bahasa Python : if, class, for, print, dll

prin = "Kaisya"

print(prin)
# Out:
# Kaisya

# %%
end = "Kaisya"

print(end)
# Out:
# Kaisya

# %%
# Tidak Deskriptif
# Bisa tapi tidak jelas/tidak deskriptif
_ = "Kaisya"

print(_)

#yang seharusnya:
nama_pelanggan = "Kesaa"

print(nama_pelanggan)
# Out:
# Kaisya
# Kesaa

# %%
# Tidak boleh pakai kata kunci Python
# Kalau eror, harus disconnect dulu
# print = "Kaisya"

#print(print)

# %% [markdown]
# #Assigment

# %% [markdown]
# ##Single Assignment

# %%
nama_siswa_2 = "Dhapne"
nama_siswa_3 = "Farel"

print(nama_siswa_2)
print(nama_siswa_3)
# Out:
# Dhapne
# Farel

# %% [markdown]
# ##Multiple Assignment

# %%
nama_siswa_4, nama_siswa_5 = "Sada", "Shello"

print(nama_siswa_4)
print(nama_siswa_5)
# Out:
# Sada
# Shello

# %% [markdown]
# ##Assign ke Banyak Variabel Sekaligus

# %%
nilai_kaisya = nilai_fazila = 100

print(nilai_kaisya)
print(nilai_fazila)
# Out:
# 100
# 100

# %% [markdown]
# ##Perubahan Nilai Variabel

# %%
nilai_kaisya = 96

print(nilai_kaisya)
# Out:
# 96

# %% [markdown]
# #Latihan Soal: Harga Barang di Swalayan
#
# Seorang kasir sedang mencatat harga beberapa barang di swalayan. Bantulah kasir dengan membuat program Python yang melakukan

# %% [markdown]
# ##Single Assignment

# %%
harga_susu = 15000
harga_roti = 12000
harga_telur = 24000

print(harga_susu)
print(harga_roti)
print(harga_telur)
# Out:
# 15000
# 12000
# 24000

# %% [markdown]
# ##Multiple Assignment

# %%
harga_gula, harga_minyak = 14000, 20000

print(harga_gula)
print(harga_minyak)
# Out:
# 14000
# 20000

# %% [markdown]
# ##Pengisian Nilai Sama

# %%
harga_mie_ayam = harga_mie_soto = harga_mie_kari = 3500

print(harga_mie_ayam)
print(harga_mie_soto)
print(harga_mie_kari)
# Out:
# 3500
# 3500
# 3500

# %% [markdown]
# ##Swap (Tukar Nilai)

# %%
harga_roti = 15000
harga_susu = 12000

# %%
print(harga_roti)
print(harga_susu)
# Out:
# 15000
# 12000

# %% [markdown]
# ##Perubahan Nilai Variabel

# %%
# Mengalami diskon

harga_telur = 24000 - 2000
harga_minyak = 20000 + 3000

print(harga_telur)
print(harga_minyak)
# Out:
# 22000
# 23000

# %% [markdown]
# #Aritmatika

# %%
print("5000*3")
# Out:
# 5000*3

# %%
# Operand tanpa disimpan dalam variabel

print(5000*3)
# Out:
# 15000

# %%
# Simpan operand ke dalam variabel

harga_kojek = 6000
banyak_porsi = 3

print(harga_kojek*banyak_porsi)
# Out:
# 18000

# %%
# Simpan hasil operasi ke dalam variabel

harga_total_kojek = 3000*3

print(harga_total_kojek)
# Out:
# 9000

# %%
# Simpan nilai operasi dan hasil operasi ke dalam variabel

harga_cilok = 10000
jumlah_porsi_cilok = 5
harga_total_cilok = harga_cilok*jumlah_porsi_cilok

print(harga_total_cilok)
# Out:
# 50000

# %%
uang_yang_diterima = 100000
uang_kembalian = uang_yang_diterima - harga_total_cilok

print(uang_kembalian)
# Out:
# 50000

# %% [markdown]
# #Soal
#
# Satu kardus berisi 24 botol minum. Jika ada 3 kardus, berapa jumlah botol?

# %%
print(24*3)
# Out:
# 72

# %%
total_jumlah_botol = 24*3

print(total_jumlah_botol)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3

print(banyak_botol_per_kardus*banyak_kardus)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3
total_jumlah_botol = 24*3

print(total_jumlah_botol)
# Out:
# 72

# %% [markdown]
# #Tipe Variabel

# %%
usia = 17

type(usia)
# Out:
# int

# %%
berat_telur = 2.5

type(berat_telur)
# Out:
# float

# %%
nama = "Kaisya"

type(nama)

# %%
remidi = False

type(remidi)
# Out:
# bool

# %%
remidi = True

type(remidi)
# Out:
# bool

# %%
koordinat_bintang = -1.5

type(koordinat_bintang)
# Out:
# float

# %%
koordinat_titik = -8

type(koordinat_titik)
# Out:
# int

# %% [markdown]
# #Input

# %%
panjang = 10
lebar = 5
luas = panjang*lebar

print(luas)
# Out:
# 50

# %%
input()
# Out:
# 10
# '10'

# %%
panjang = input()
# Out:
# 10

# %%
print(panjang)
# Out:
# 10

# %%
lebar = input()
# Out:
# 5

# %%
print(lebar)
# Out:
# 5

# %%
luas = panjang*lebar

print(luas)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-508063834.py in <cell line: 0>()
# ----> 1 luas = panjang*lebar
#       2
#       3 print(luas)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
type(panjang)
# Out:
# str

# %%
type(lebar)
# Out:
# str

# %%
panjang = int(panjang)

# %%
lebar = int(lebar)

# %%
type(panjang)
# Out:
# str

# %%
panjang_1 = int(input("Masukan panjang persegi: "))
# Out:
# Masukan panjang persegi: 10

# %%
panjang_2 = int(input("Masukan panjang persegi: "))
lebar_2 = int(input("Masukan lebar persegi: "))

luas_2 = panjang_2*lebar_2

print(f"Luas persegi panjang adalah {luas_2} cm^2")
# Out:
# Masukan panjang persegi: 4
# Masukan lebar persegi: 10
# Luas persegi panjang adalah 40 cm^2

# %%
#Tugas Menghitung Volume Balok

panjang = int(input("Masukkan panjang Balok (dalam cm): "))
lebar = int(input("Masukkan lebar Balok (dalam cm): "))
tinggi = int(input("Masukkan tinggi Balok (dalam cm): "))

volume = panjang*lebar*tinggi

print(f"Volume Balok adalah: {volume} cm^2")
# Out:
# Masukkan panjang Balok (dalam cm): 10
# Masukkan lebar Balok (dalam cm): 5
# Masukkan tinggi Balok (dalam cm): 4
# Volume Balok adalah: 200 cm^2

# %% [markdown]
# #Konversi Tipe Data

# %%
a = 3

print(a)
type(a)
# Out:
# 3
# int

# %%
a = float(a)

print(a)
type(a)
# Out:
# 3.0
# float

# %%
a = str(a)

print(a)
type(a)
# Out:
# 3.0
# str

# %%
a = bool(a)

print(a)
type(a)
# Out:
# True
# bool

# %%
b = "cicak"
print(b)

b = bool(b)
print(b)
# Out:
# cicak
# True

# %%
c = ""
print(c)

c = bool(c)
print(c)
# Out:
# False

# %%
d = False

print(d)
type(d)
# Out:
# False
# bool

# %%
e = "False"

print(e)
type(e)
# Out:
# False
# str

# %% [markdown]
# #Operator Perbandingan

# %%
print(8<5)
# Out:
# False

# %%
print(8>5)
# Out:
# True

# %%
print(9>=9)
# Out:
# True

# %%
print(8 == 5)
# Out:
# False

# %%
print(8 == 8)
# Out:
# True

# %%
print(1 != 1)
# Out:
# False

# %%
a = 10
b = 20
c = 30

print(a>c)
# Out:
# False

# %%
print(a>30)
# Out:
# False

# %%
nilai_kka = 75
kkm_kka = 80

print(nilai_kka > kkm_kka)
# Out:
# False

# %% [markdown]
# #Operator Logika

# %%
print(8>7 and 5>6)
# Out:
# False

# %%
print(8>7 and 5<6)
# Out:
# True

# %%
print(8>7 or 5>6)
# Out:
# True

# %%
print(not(8>7 or 5>6))
# Out:
# False

# %%
print(not(8>=9 or 9 != 8))
# Out:
# False

# %%
iq_min = 125
tinggi_min = 165

print(125 >= iq_min and 170 >= tinggi_min)
# Out:
# True

# %%
iq_afa = 125
tinggi_afa = 170

print(iq_afa >= iq_min and tinggi_afa >= tinggi_min)
# Out:
# True

# %%
# Soal Pendaftaran Taruna
# Syarat:
tinggi_min = 165
BB_min = 50
umur_max = 25

tinggi_farrel = 170
BB_farrel = 55
umur_farrel = 23

print(tinggi_farrel >= tinggi_min and BB_farrel >= BB_min and umur_farrel <= umur_max )
# Out:
# True
